# %% [markdown]
# ## Init & version check

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

print('numpy: {}'.format(np.__version__))
print('pandas: {}'.format(pd.__version__))
print('matplotlib: {}'.format(matplotlib.__version__))
print('seaborn: {}'.format(sns.__version__))
print('scikit-learn: {}'.format(sklearn.__version__))
# Out:
# numpy: 1.19.2
# pandas: 1.1.3
# matplotlib: 3.3.2
# seaborn: 0.11.0
# scikit-learn: 0.23.2

# %% [markdown]
# ## Titanic Data DL

# %%
import pandas as pd
import numpy as np
 
# train data
train = pd.read_csv('https://raw.githubusercontent.com/kotaronov27/KaggleSB/main/Titanic/data/train.csv')
# org create
train_org = train.copy()
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# test data
test = pd.read_csv('https://raw.githubusercontent.com/kotaronov27/KaggleSB/main/Titanic/data/test.csv')
# org create
test_org = test.copy()
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# test data
gendersb = pd.read_csv('https://raw.githubusercontent.com/kotaronov27/KaggleSB/main/Titanic/data/gender_submission.csv')
# org create
gendersb_org = gendersb.copy()
gendersb.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.countplot('Sex', data=train)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot('Pclass', data=train)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot('Age', data=train)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.distplot(train['Age'].dropna(), kde=False, bins=16)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
# 家族（兄弟配偶者でcountplot）
sns.countplot('SibSp', data=train)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
# 家族（親子供でcountplot）
sns.countplot('Parch', data=train)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
# チケット
sns.countplot('Ticket', data=train)
# Out:
# <AxesSubplot:xlabel='Ticket', ylabel='count'>

# %%
# チケット行確認
train['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
# 番号部分抽出
def extract_ticket_number(x):
  ticket = x['Ticket']
  return ticket.split(" ")[-1]

# チケット番号を取り出した列を追加
train['TicketNumber'] = train.apply(extract_ticket_number, axis=1)

# 番号でソートして、先頭10行を取り出す
train.sort_values(by='TicketNumber')[0:10]
# Out:
#      PassengerId  Survived  Pclass  \
# 283          284         1       3
# 257          258         1       1
# 504          505         1       1
# 759          760         1       1
# 262          263         0       1
# 585          586         1       1
# 558          559         1       1
# 475          476         0       1
# 110          111         0       1
# 430          431         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 283                         Dorking, Mr. Edward Arthur    male  19.0      0
# 257                               Cherry, Miss. Gladys  female  30.0      0
# 504                              Maioni, Miss. Roberta  female  16.0      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 262                                  Taussig, Mr. Emil    male  52.0      1
# 585                                Taussig, Miss. Ruth  female  18.0      0
# 558             Taussig, Mrs. Emil (Tillie Mandelbaum)  female  39.0      1
# 475                        Clifford, Mr. George Quincy    male   NaN      0
# 110                     Porter, Mr. Walter Chamberlain    male  47.0      0
# 430          Bjornstrom-Steffansson, Mr. Mauritz Hakan    male  28.0      0
#
#      Parch      Ticket   Fare Cabin Embarked TicketNumber
# 283      0  A/5. 10482   8.05   NaN        S        10482
# 257      0      110152  86.50   B77        S       110152
# 504      0      110152  86.50   B79        S       110152
# 759      0      110152  86.50   B77        S       110152
# 262      1      110413  79.65   E67        S       110413
# 585      2      110413  79.65   E68        S       110413
# 558      1      110413  79.65   E67        S       110413
# 475      0      110465  52.00   A14        S       110465
# 110      0      110465  52.00  C110        S       110465
# 430      0      110564  26.55   C52        S       110564

# %%
#Fare
sns.countplot('Fare', data=train)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='count'>

# %%
#Fare ヒストグラム
sns.distplot(train['Fare'], kde=False)
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
#Fare 料金ソート
train.sort_values(by='Fare')[0:20]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 263          264         0       1             Harrison, Mr. William  male
# 466          467         0       2             Campbell, Mr. William  male
# 732          733         0       2              Knight, Mr. Robert J  male
# 179          180         0       3               Leonard, Mr. Lionel  male
# 806          807         0       1            Andrews, Mr. Thomas Jr  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 822          823         0       1   Reuchlin, Jonkheer. John George  male
# 815          816         0       1                  Fry, Mr. Richard  male
# 378          379         0       3               Betros, Mr. Tannous  male
# 872          873         0       1          Carlsson, Mr. Frans Olof  male
# 326          327         0       3         Nysveen, Mr. Johan Hansen  male
# 843          844         0       3        Lemberopolous, Mr. Peter L  male
# 818          819         0       3  Holm, Mr. John Fredrik Alexander  male
#
#       Age  SibSp  Parch  Ticket    Fare        Cabin Embarked TicketNumber
# 271  25.0      0      0    LINE  0.0000          NaN        S         LINE
# 597  49.0      0      0    LINE  0.0000          NaN        S         LINE
# 302  19.0      0      0    LINE  0.0000          NaN        S         LINE
# 633   NaN      0      0  112052  0.0000          NaN        S       112052
# 277   NaN      0      0  239853  0.0000          NaN        S       239853
# 413   NaN      0      0  239853  0.0000          NaN        S       239853
# 674   NaN      0      0  239856  0.0000          NaN        S       239856
# 263  40.0      0      0  112059  0.0000          B94        S       112059
# 466   NaN      0      0  239853  0.0000          NaN        S       239853
# 732   NaN      0      0  239855  0.0000          NaN        S       239855
# 179  36.0      0      0    LINE  0.0000          NaN        S         LINE
# 806  39.0      0      0  112050  0.0000          A36        S       112050
# 481   NaN      0      0  239854  0.0000          NaN        S       239854
# 822  38.0      0      0   19972  0.0000          NaN        S        19972
# 815   NaN      0      0  112058  0.0000         B102        S       112058
# 378  20.0      0      0    2648  4.0125          NaN        C         2648
# 872  33.0      0      0     695  5.0000  B51 B53 B55        S          695
# 326  61.0      0      0  345364  6.2375          NaN        S       345364
# 843  34.5      0      0    2683  6.4375          NaN        C         2683
# 818  43.0      0      0  C 7075  6.4500          NaN        S         7075

# %%
#Cabin
sns.countplot("Cabin", data=train)
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='count'>

# %%
#Cabin sort
train.sort_values(by='Cabin')[0:20]
# Out:
#      PassengerId  Survived  Pclass  \
# 583          584         0       1
# 475          476         0       1
# 556          557         1       1
# 284          285         0       1
# 599          600         1       1
# 630          631         1       1
# 867          868         0       1
# 647          648         1       1
# 209          210         1       1
# 185          186         0       1
# 445          446         1       1
# 806          807         0       1
# 96            97         0       1
# 23            24         1       1
# 174          175         0       1
# 737          738         1       1
# 815          816         0       1
# 523          524         1       1
# 329          330         1       1
# 170          171         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 583                                Ross, Mr. John Hugo    male  36.0      0
# 475                        Clifford, Mr. George Quincy    male   NaN      0
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0      1
# 284                         Smith, Mr. Richard William    male   NaN      0
# 599       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0      1
# 630               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 647                Simonius-Blumer, Col. Oberst Alfons    male  56.0      0
# 209                                   Blank, Mr. Henry    male  40.0      0
# 185                              Rood, Mr. Hugh Roscoe    male   NaN      0
# 445                          Dodge, Master. Washington    male   4.0      0
# 806                             Andrews, Mr. Thomas Jr    male  39.0      0
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 174                            Smith, Mr. James Clinch    male  56.0      0
# 737                             Lesurer, Mr. Gustave J    male  35.0      0
# 815                                   Fry, Mr. Richard    male   NaN      0
# 523    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female  44.0      0
# 329                       Hippach, Miss. Jean Gertrude  female  16.0      0
# 170                          Van der hoef, Mr. Wyckoff    male  61.0      0
#
#      Parch    Ticket      Fare Cabin Embarked TicketNumber
# 583      0     13049   40.1250   A10        C        13049
# 475      0    110465   52.0000   A14        S       110465
# 556      0     11755   39.6000   A16        C        11755
# 284      0    113056   26.0000   A19        S       113056
# 599      0  PC 17485   56.9292   A20        C        17485
# 630      0     27042   30.0000   A23        S        27042
# 867      0  PC 17590   50.4958   A24        S        17590
# 647      0     13213   35.5000   A26        C        13213
# 209      0    112277   31.0000   A31        C       112277
# 185      0    113767   50.0000   A32        S       113767
# 445      2     33638   81.8583   A34        S        33638
# 806      0    112050    0.0000   A36        S       112050
# 96       0  PC 17754   34.6542    A5        C        17754
# 23       0    113788   35.5000    A6        S       113788
# 174      0     17764   30.6958    A7        C        17764
# 737      0  PC 17755  512.3292  B101        C        17755
# 815      0    112058    0.0000  B102        S       112058
# 523      1    111361   57.9792   B18        C       111361
# 329      1    111361   57.9792   B18        C       111361
# 170      0    111240   33.5000   B19        S       111240

# %%
#Cabin sort (reverse)
train.sort_values(by='Cabin', ascending=False)[0:20]
# Out:
#      PassengerId  Survived  Pclass  \
# 339          340         0       1
# 394          395         1       3
# 205          206         0       3
# 251          252         0       3
# 10            11         1       3
# 183          184         1       2
# 618          619         1       2
# 776          777         0       3
# 66            67         1       2
# 345          346         1       2
# 516          517         1       2
# 193          194         1       2
# 340          341         1       2
# 148          149         0       2
# 75            76         0       3
# 715          716         0       3
# 699          700         0       3
# 128          129         1       3
# 809          810         1       1
# 724          725         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 339                       Blackwell, Mr. Stephen Weart    male  45.0      0
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 205                         Strom, Miss. Telma Matilda  female   2.0      0
# 251         Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 183                          Becker, Master. Richard F    male   1.0      2
# 618                        Becker, Miss. Marion Louise  female   4.0      2
# 776                                   Tobin, Mr. Roger    male   NaN      0
# 66                        Nye, Mrs. (Elizabeth Ramell)  female  29.0      0
# 345                      Brown, Miss. Amelia "Mildred"  female  24.0      0
# 516                       Lemore, Mrs. (Amelia Milley)  female  34.0      0
# 193                         Navratil, Master. Michel M    male   3.0      1
# 340                     Navratil, Master. Edmond Roger    male   2.0      1
# 148           Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5      0
# 75                             Moen, Mr. Sigurd Hansen    male  25.0      0
# 715         Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.0      0
# 699           Humblen, Mr. Adolf Mathias Nicolai Olsen    male  42.0      0
# 128                                  Peter, Miss. Anna  female   NaN      1
# 809     Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.0      1
# 724                      Chambers, Mr. Norman Campbell    male  27.0      1
#
#      Parch      Ticket     Fare  Cabin Embarked TicketNumber
# 339      0      113784  35.5000      T        S       113784
# 394      2     PP 9549  16.7000     G6        S         9549
# 205      1      347054  10.4625     G6        S       347054
# 251      1      347054  10.4625     G6        S       347054
# 10       1     PP 9549  16.7000     G6        S         9549
# 183      1      230136  39.0000     F4        S       230136
# 618      1      230136  39.0000     F4        S       230136
# 776      0      383121   7.7500    F38        Q       383121
# 66       0  C.A. 29395  10.5000    F33        S        29395
# 345      0      248733  13.0000    F33        S       248733
# 516      0  C.A. 34260  10.5000    F33        S        34260
# 193      1      230080  26.0000     F2        S       230080
# 340      1      230080  26.0000     F2        S       230080
# 148      2      230080  26.0000     F2        S       230080
# 75       0      348123   7.6500  F G73        S       348123
# 715      0      348124   7.6500  F G73        S       348124
# 699      0      348121   7.6500  F G63        S       348121
# 128      1        2668  22.3583  F E69        C         2668
# 809      0      113806  53.1000     E8        S       113806
# 724      0      113806  53.1000     E8        S       113806

# %%
# 番号部分を取り出す(T は誤りとして処理)
def extract_cabin_type(x):
  cabin = x['Cabin']
  if isinstance(cabin, str) and cabin[0] != 'T':
    return cabin[0]
  else:
    return np.nan

# 訓練データとテストデータの両方に、チケット番号を取り出したCabinType列を追加
train['CabinType'] = train.apply(extract_cabin_type, axis=1)
test['CabinType'] = test.apply(extract_cabin_type, axis=1)

sortedCabinTypes = sorted(set(train['CabinType'].dropna()))

sns.countplot("CabinType", data=train, order=sortedCabinTypes)
# Out:
# <AxesSubplot:xlabel='CabinType', ylabel='count'>

# %%
# 子供、男性、女性に分類
def male_female_child(x):
  age = x['Age']
  sex = x['Sex']
  # 15歳以下なら子供、それ以外を male / female に分ける
  if age <= 15:
    return 'child'
  else:
    return sex

# 訓練データとテストデータの両方に、male / female / childに分けたPersonType列を追加
train['PersonType'] = train.apply(male_female_child,axis=1)
test['PersonType'] = test.apply(male_female_child,axis=1)

sns.countplot('PersonType', data=train)
# Out:
# <AxesSubplot:xlabel='PersonType', ylabel='count'>

# %%
# チケットクラスごとに分類
sns.countplot('Pclass', data=train, hue='PersonType')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
# カーネル密度分布
# チケットクラスで層別化して、グラフを少し横長に設定
fig = sns.FacetGrid(train, hue="Pclass",aspect=4)

# チケットクラスごとにkdeplotを描く
fig.map(sns.kdeplot, 'Age', shade=True)

# 横軸の表示範囲を設定
oldest = train['Age'].max()
fig.set(xlim=(0,oldest))

# 凡例を表示
fig.add_legend()

# %%
# 乗船可視化
#Southampton(S)
#Cherbourg(C)
#Queenstown(Q)
sns.countplot('Embarked', data=train, hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
# 訓練データとテストデータのそれぞれについて、FamilySize列を追加する
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

sns.countplot('FamilySize', data=train)
# Out:
# <AxesSubplot:xlabel='FamilySize', ylabel='count'>

# %%
sns.countplot('FamilySize', data=train, hue='Pclass')
# Out:
# <AxesSubplot:xlabel='FamilySize', ylabel='count'>

# %%
# 解析メイン（死亡率）
# チケットクラス
sns.catplot('Pclass', 'Survived', data=train, order=[1,2,3], kind='point')

# %%
# 年齢、男女で分ける
sns.catplot('Pclass', 'Survived', hue='PersonType', data=train, order=[1,2,3], kind='point')

# %%
# 年齢での生死
sns.lmplot('Age', 'Survived', data=train)

# %%
# チケットクラスごと
sns.lmplot('Age', 'Survived', hue='Pclass', data=train, palette='winter', hue_order=[1,2,3])

# %%
# x_binsで指定した年齢について、生存確率の推定値を表示
sns.lmplot('Age','Survived',hue='Pclass',data=train, palette='winter', x_bins=[10,20,40,60,80], hue_order=[1,2,3])

# %%
# 性別、年齢ごと
sns.lmplot('Age', 'Survived', hue='Sex', data=train, x_bins=[10,20,40,60,80])

# %%
# 料金と生死
fig = sns.lmplot('Fare', 'Survived', data=train)

# X軸の範囲を0から100に限定
fig.set(xlim=(0,100))

# %%
# 家族と生死
sns.lmplot('FamilySize', 'Survived', data=train, x_bins=[1, 2, 3, 4, 5, 6, 7, 8, 9])

# %%
# 家族と子供、男性、女性でプロット
sns.lmplot('FamilySize', 'Survived', hue='PersonType', data=train, x_bins=[1, 2, 3, 4, 5, 6, 7, 8, 9])
